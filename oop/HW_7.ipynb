# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.datasets import fetch_openml

# %%
# Import dataset
X,y = fetch_openml("autos", version=1, as_frame=True, return_X_y=True)
data = X
data['target'] = y

# %% [markdown]
# # Q1

# %%
X
# Out:
#      normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                  NaN  alfa-romero       gas        std          two
# 1                  NaN  alfa-romero       gas        std          two
# 2                  NaN  alfa-romero       gas        std          two
# 3                164.0         audi       gas        std         four
# 4                164.0         audi       gas        std         four
# ..                 ...          ...       ...        ...          ...
# 200               95.0        volvo       gas        std         four
# 201               95.0        volvo       gas      turbo         four
# 202               95.0        volvo       gas        std         four
# 203               95.0        volvo    diesel      turbo         four
# 204               95.0        volvo       gas      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  \
# ...

# %%
a1 = X.pivot_table(values = 'price', index = 'num-of-doors', columns = 'fuel-type')
a1
# Out:
# fuel-type        diesel           gas
# num-of-doors
# four          16432.375  13092.814433
# two           14350.000  12762.759036

# %%
a1.round(2)
# Out:
# fuel-type       diesel       gas
# num-of-doors
# four          16432.38  13092.81
# two           14350.00  12762.76

# %%
X.pivot_table(values = 'price', 
              index = ['num-of-doors', 'body-style'], columns = ['fuel-type', 'fuel-system'])
# Out:
# fuel-type                       diesel          gas                        \
# fuel-system                        idi         1bbl         2bbl     4bbl
# num-of-doors body-style
# four         wagon        19727.666667  7295.000000  8028.888889      NaN
#              sedan        16328.916667  8811.666667  7711.190476      NaN
#              hatchback     7788.000000          NaN  7813.714286      NaN
# two          hardtop      28176.000000          NaN  8249.000000      NaN
#              sedan         7437.000000          NaN  7570.000000      NaN
#              hatchback             NaN  7054.428571  6701.666667  12145.0
#              convertible           NaN          NaN          NaN      NaN
#
# fuel-type
# fuel-system                   mfi          mpfi          spdi     spfi
# num-of-doors body-style
# four         wagon            NaN  14213.416667           NaN      NaN
#              sedan            NaN  18425.675000   9279.000000      NaN
# ...

# %%
X.pivot_table(values = 'price',
              index = ['num-of-doors', 'body-style'], columns = ['fuel-type', 'fuel-system'],
              fill_value = 0)
# Out:
# fuel-type                       diesel          gas                      \
# fuel-system                        idi         1bbl         2bbl   4bbl
# num-of-doors body-style
# four         wagon        19727.666667  7295.000000  8028.888889      0
#              sedan        16328.916667  8811.666667  7711.190476      0
#              hatchback     7788.000000     0.000000  7813.714286      0
# two          hardtop      28176.000000     0.000000  8249.000000      0
#              sedan         7437.000000     0.000000  7570.000000      0
#              hatchback        0.000000  7054.428571  6701.666667  12145
#              convertible      0.000000     0.000000     0.000000      0
#
# fuel-type
# fuel-system                 mfi          mpfi          spdi   spfi
# num-of-doors body-style
# four         wagon            0  14213.416667      0.000000      0
#              sedan            0  18425.675000   9279.000000      0
# ...

# %% [markdown]
# # Q2

# %%
X.pivot_table(values = 'price',
             index = 'body-style', columns = 'num-of-doors',
             aggfunc = {'mean', 'median'})
# Out:
#                       mean                 median
# num-of-doors          four           two     four      two
# body-style
# hardtop                NaN  22208.500000      NaN  19687.5
# wagon         12371.960000           NaN  11694.0      NaN
# sedan         14614.128205  14283.000000  12555.0   8678.0
# hatchback      8372.000000  10230.793103   8073.0   8970.0
# convertible            NaN  21890.500000      NaN  17084.5

# %%
X.pivot_table(values = 'price',
             index = 'body-style', columns = 'num-of-doors',
             aggfunc = {'mean', 'median'},
             fill_value = 0)
# Out:
#                       mean               median
# num-of-doors          four           two   four      two
# body-style
# hardtop           0.000000  22208.500000      0  19687.5
# wagon         12371.960000      0.000000  11694      0.0
# sedan         14614.128205  14283.000000  12555   8678.0
# hatchback      8372.000000  10230.793103   8073   8970.0
# convertible       0.000000  21890.500000      0  17084.5

# %%
X.pivot_table(values = ['price', 'horsepower'], index = 'make')
# Out:
#                horsepower         price
# make
# alfa-romero    125.333333  15498.333333
# audi           121.000000  17859.166667
# bmw            138.875000  26118.750000
# chevrolet       62.666667   6007.000000
# dodge           86.333333   7875.444444
# honda           80.230769   8184.692308
# isuzu           77.000000   8916.500000
# jaguar         204.666667  34600.000000
# mazda           85.529412  10652.882353
# mercedes-benz  146.250000  33647.000000
# mercury        175.000000  16503.000000
# mitsubishi     104.076923   9239.769231
# nissan         102.555556  10415.666667
# peugot          99.818182  15489.090909
# plymouth        86.714286   7963.428571
# porsche        210.400000  31400.500000
# renault               NaN   9595.000000
# saab           126.666667  15223.333333
# subaru          86.250000   8541.250000
# toyota          92.781250   9885.812500
# volkswagen      81.083333  10077.500000
# volvo          128.000000  18063.181818

# %%
a2 = X.pivot_table(['price', 'horsepower'], index = 'make', fill_value = 0)
a2 = a2.round(2)
a2
# Out:
#                horsepower     price
# make
# alfa-romero        125.33  15498.33
# audi               121.00  17859.17
# bmw                138.88  26118.75
# chevrolet           62.67   6007.00
# dodge               86.33   7875.44
# honda               80.23   8184.69
# isuzu               77.00   8916.50
# jaguar             204.67  34600.00
# mazda               85.53  10652.88
# mercedes-benz      146.25  33647.00
# mercury            175.00  16503.00
# mitsubishi         104.08   9239.77
# nissan             102.56  10415.67
# peugot              99.82  15489.09
# plymouth            86.71   7963.43
# porsche            210.40  31400.50
# renault              0.00   9595.00
# saab               126.67  15223.33
# subaru              86.25   8541.25
# toyota              92.78   9885.81
# volkswagen          81.08  10077.50
# volvo              128.00  18063.18

# %%
a2.sort_values(by = 'price', ascending = False)
# Out:
#                horsepower     price
# make
# jaguar             204.67  34600.00
# mercedes-benz      146.25  33647.00
# porsche            210.40  31400.50
# bmw                138.88  26118.75
# volvo              128.00  18063.18
# audi               121.00  17859.17
# mercury            175.00  16503.00
# alfa-romero        125.33  15498.33
# peugot              99.82  15489.09
# saab               126.67  15223.33
# mazda               85.53  10652.88
# nissan             102.56  10415.67
# volkswagen          81.08  10077.50
# toyota              92.78   9885.81
# renault              0.00   9595.00
# mitsubishi         104.08   9239.77
# isuzu               77.00   8916.50
# subaru              86.25   8541.25
# honda               80.23   8184.69
# plymouth            86.71   7963.43
# dodge               86.33   7875.44
# chevrolet           62.67   6007.00

# %% [markdown]
# # Q3

# %%
import datetime

# %%
datetime.date(2022, 11, 8)
# Out:
# datetime.date(2022, 11, 8)

# %%
datetime.datetime(2022, 11, 8, 11, 18, 7, 490703)
# Out:
# datetime.datetime(2022, 11, 8, 11, 18, 7, 490703)

# %%
now = datetime.datetime.today()
now
# Out:
# datetime.datetime(2022, 11, 8, 23, 20, 12, 47778)

# %%
yester = now - datetime.timedelta(days = 1)
yester
# Out:
# datetime.datetime(2022, 11, 7, 23, 20, 12, 47778)

# %%
yester.year
# Out:
# 2022

# %% [markdown]
# # Q4

# %%
pd.date_range('2022-11-08', '2022-11-14')
# Out:
# DatetimeIndex(['2022-11-08', '2022-11-09', '2022-11-10', '2022-11-11',
#                '2022-11-12', '2022-11-13', '2022-11-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
a4 = pd.date_range('2022-11-15', periods = 18, freq = 'W')
a4
# Out:
# DatetimeIndex(['2022-11-20', '2022-11-27', '2022-12-04', '2022-12-11',
#                '2022-12-18', '2022-12-25', '2023-01-01', '2023-01-08',
#                '2023-01-15', '2023-01-22', '2023-01-29', '2023-02-05',
#                '2023-02-12', '2023-02-19', '2023-02-26', '2023-03-05',
#                '2023-03-12', '2023-03-19'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
print(a4.min())
print(a4.max())
# Out:
# 2022-11-20 00:00:00
# 2023-03-19 00:00:00
