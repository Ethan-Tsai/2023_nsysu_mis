# %%
import pandas as pd
pd.read_csv("EF23Y01.csv")
# Out:
#       期間  資產合計=負債權益合計-原始值 資產合計=負債權益合計-年增率  國外資產-原始值  國外資產-年增率 對政府放款及墊款-原始值  \
# 0   1987          2768757               -   2264210         -         2483
# 1   1988          2732883               -   2233670         -         2049
# 2   1989          2754023         0.77354   2068915  -7.37598         2044
# 3   1990          2646854        -3.89136   2116554   2.30261         2043
# 4   1991          2933561        10.83199   2274610   7.46761         2042
# 5   1992          2988365         1.86817   2244136  -1.33975         2041
# 6   1993          2963396        -0.83554   2381601   6.12552         2041
# 7   1994          3166452         6.85214   2579694   8.31764         2040
# 8   1995          3100536        -2.08170   2617124   1.45095         2040
# 9   1996          3141693         1.32742   2573175  -1.67929         2040
# 10  1997          3360411         6.96179   2875757  11.75909         2040
# ...

# %%
a=pd.read_csv("184d09aaaaf62f52182c0391f1d95c3c.csv")
print(a.shape)
# Out:
# (37, 10)

# %%
pd.read_csv("STOCK_DAY_ALL_20221207.csv")
# Out:
#       證券代號      證券名稱        成交股數         成交金額     開盤價     最高價     最低價     收盤價  \
# 0     0050    元大台灣50   8129000.0  933888500.0  114.50  115.85  114.20  114.60
# 1     0051   元大中型100     20000.0    1052600.0   53.15   53.15   52.15   52.70
# 2     0052      富邦科技    245000.0   23990700.0   98.00   98.95   97.45   97.45
# 3     0053      元大電子      4000.0     220000.0   54.70   55.30   54.70   54.95
# 4     0055  元大MSCI金融    203000.0    4440320.0   21.74   22.00   21.74   21.91
# ...    ...       ...         ...          ...     ...     ...     ...     ...
# 1174  9944        新麗    143000.0    2946250.0   20.60   20.65   20.50   20.60
# 1175  9945       潤泰新  11136000.0  509978150.0   45.95   46.30   45.20   45.60
# 1176  9946      三發地產     72000.0     888100.0   12.30   12.40   12.25   12.35
# 1177  9955        佳龍    595000.0   12032050.0   20.60   20.60   19.85   20.25
# 1178  9958       世紀鋼   7582000.0  666062200.0   89.60   90.90   85.70   85.90
#
#       漲跌價差    成交筆數
# ...

# %%
b=pd.read_csv("opendata110N010.csv")
pd.options.display.max_columns=None;
pd.options.display.max_rows=None;
print(b)
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             110                                             新北市板橋區
# 2             110                                             新北市三重區
# 3             110                                             新北市中和區
# 4             110                                             新北市永和區
# 5             110                                             新北市新莊區
# 6             110                                             新北市新店區
# 7             110                                             新北市樹林區
# 8             110                                             新北市鶯歌區
# 9             110                                             新北市三峽區
# 10            110                                             新北市淡水區
# 11            110                                             新北市汐止區
# 12            110                                             新北市瑞芳區
# ...

# %%
c=pd.read_csv("t187ap03_O.csv")
c
print(c)
# Out:
#         出表日期  公司代號               公司名稱       公司簡稱  \
# 0    1111206  1240         茂生農經股份有限公司       茂生農經
# 1    1111206  1258       其祥生物科技控股有限公司      其祥-KY
# 2    1111206  1259       安心食品服務股份有限公司         安心
# 3    1111206  1264         德麥食品股份有限公司         德麥
# 4    1111206  1268         漢來美食股份有限公司       漢來美食
# 5    1111206  1336       台翰精密科技股份有限公司         台翰
# 6    1111206  1565         精華光學股份有限公司         精華
# 7    1111206  1569         濱川企業股份有限公司         濱川
# 8    1111206  1570         力肯實業股份有限公司         力肯
# 9    1111206  1580         新麥企業股份有限公司         新麥
# 10   1111206  1584       精剛精密科技股份有限公司         精剛
# 11   1111206  1586         和勤精機股份有限公司         和勤
# 12   1111206  1591   英屬開曼群島商駿吉控股(股)公司      駿吉-KY
# 13   1111206  1593           祺驊股份有限公司         祺驊
# 14   1111206  1595         川寶科技股份有限公司         川寶
# 15   1111206  1599      宏佳騰動力科技股份有限公司        宏佳騰
# 16   1111206  1742         台灣蠟品股份有限公司         台蠟
# 17   1111206  1777       生泰合成工業股份有限公司         生泰
# ...

# %%
d=pd.read_csv("COA_OpenData.csv")
# Out:
#            交易日期 種類代碼   作物代號         作物名稱  市場代號  市場名稱     上價     中價     下價  \
# 0     111.12.07  N05     22           棗子   104   台北二  156.0   96.4   59.9
# 1     111.12.07  N05    469      藍莓-進口藍莓   104   台北二  133.3  133.3  133.3
# 2     111.12.07  N05     51      百香果-改良種   104   台北二   82.3   40.8   25.6
# 3     111.12.07  N05    811       火龍果-白肉   104   台北二  107.8   76.4   53.7
# 4     111.12.07  N05     A0        香蕉-其他   104   台北二    8.0    6.4    6.0
# 5     111.12.07  N05     A4        香蕉-越旦   104   台北二   22.1   18.0   13.5
# 6     111.12.07  N05     B2      鳳梨-金鑽鳳梨   104   台北二   32.5   21.8   11.5
# 7     111.12.07  N05     C6      佛利檬-佛利檬   104   台北二   60.0   48.0   23.8
# 8     111.12.07  NaN     C8          NaN   104   台北二  103.9   66.3   34.2
# 9     111.12.07  N05     C9        椪柑-進口   104   台北二  113.8   37.0   37.0
# 10    111.12.07  N05     E0        甜橙-其他   104   台北二   60.0   56.1   55.0
# 11    111.12.07  N05     F0        雜柑-其他   104   台北二   35.0   24.0   14.2
# ...

# %%
import pandas as pd
e=pd.read_csv("opendata10502M010.csv")
e
# Out:
#      statistic_yyymm site_id village birth_total birth_total_m birth_total_f  \
# 0               統計年月     區域別      村里         出生數         出生數-男         出生數-女
# 1              10502  新北市板橋區     留侯里           1             1             0
# 2              10502  新北市板橋區     流芳里           0             0             0
# 3              10502  新北市板橋區     赤松里           0             0             0
# 4              10502  新北市板橋區     黃石里           0             0             0
# ...              ...     ...     ...         ...           ...           ...
# 7847           10502  連江縣莒光鄉     西坵村           0             0             0
# 7848           10502  連江縣莒光鄉     福正村           1             1             0
# 7849           10502  連江縣莒光鄉     大坪村           0             0             0
# 7850           10502  連江縣東引鄉     中柳村           0             0             0
# 7851           10502  連江縣東引鄉     樂華村           1             1             0
#
# ...

# %%
f=pd.read_csv("opendata10902M010.csv")
f.max('birth_total')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     549         try:
# --> 550             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551         except KeyError:
#
# KeyError: 'birth_total'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14404\4200225037.py in <module>
#       1 f=pd.read_csv("opendata10902M010.csv")
# ----> 2 f.max('birth_total')
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   11217             **kwargs,
#   11218         ):
# > 11219             return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11220
#   11221         setattr(cls, "max", max)
#
# ...

# %%
f.sort_values('birth_total',ascending=False).head(30)
# Out:
#      statistic_yyymm district_code site_id village birth_total birth_total_m  \
# 0               統計年月         區域別代碼     區域別      村里         出生數         出生數-男
# 1778           10902   68000060019  桃園市大園區     南港里           9             7
# 3467           10902   64000052025  高雄市三民二     寶業里           9             4
# 1120           10902   63000030014  臺北市大安區     古莊里           9             2
# 1843           10902   68000080033  桃園市八德區     大明里           9             3
# 234            10902   65000020108  新北市三重區     碧華里           9             3
# 1811           10902   68000080001  桃園市八德區     興仁里           9             7
# 3702           10902   64000110022  高雄市小港區     山明里           9             3
# 1803           10902   68000070025  桃園市龜山區     迴龍里           9             5
# 4417           10902   10004010027  新竹縣竹北市     東興里           9             5
# 1601           10902   68000020034  桃園市中壢區     文化里           9             5
# ...
