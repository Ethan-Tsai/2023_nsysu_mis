# %% [markdown]
# # 0921

# %%
import numpy as np

# %%
x=np.arange(4)

# %%
x
# Out:
# array([0, 1, 2, 3])

# %%
x+5
# Out:
# array([5, 6, 7, 8])

# %%
print("subtraction",x-5)
# Out:
# subtraction [-5 -4 -3 -2]

# %%
print("multiply",x*5)
# Out:
# multiply [ 0  5 10 15]

# %%
print("division",x/5)
# Out:
# division [0.  0.2 0.4 0.6]

# %%
print("power",x**2)
# Out:
# power [0 1 4 9]

# %%
print("mod",x%2)
# Out:
# mod [0 1 0 1]

# %%
np.add(x,2)
# Out:
# array([2, 3, 4, 5])

# %%
np.subtract(x,2)
# Out:
# array([-2, -1,  0,  1])

# %%
np.negative(x)
# Out:
# array([ 0, -1, -2, -3])

# %%
np.multiply(x,4)
# Out:
# array([ 0,  4,  8, 12])

# %%
np.divide(x,2)
# Out:
# array([0. , 0.5, 1. , 1.5])

# %%
np.floor_divide(x,2)
# Out:
# array([0, 0, 1, 1], dtype=int32)

# %%
np.mod(x,2)
# Out:
# array([0, 1, 0, 1], dtype=int32)

# %%
x=np.array([-2,-1,0,1,2])

# %%
x
# Out:
# array([-2, -1,  0,  1,  2])

# %%
abs(x)
# Out:
# array([2, 1, 0, 1, 2])

# %%
print("abs=",np.absolute(x))
# Out:
# abs= [2 1 0 1 2]

# %%
L=np.random.random(100)

# %%
sum(L)
# Out:
# 45.50841499855533

# %%
np.sum(L)
# Out:
# 45.50841499855533

# %%
# %timeit sum(L)
# %timeit np.sum(L)
# Out:
# 6.37 µs ± 89.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 2.87 µs ± 34.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
big_array=np.random.random(100000)

# %%
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 5.69 ms ± 89 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 33.5 µs ± 667 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
print(np.min(L))
print(np.max(L))
# Out:
# 0.03160894040839446
# 0.9683113774763291

# %%
print(big_array.min(),big_array.max(),big_array.sum())
# Out:
# 1.4676059423179844e-05 0.9999989917132657 49883.658430468386

# %%
M=np.random.random((3,3))

# %%
M
# Out:
# array([[0.86129005, 0.30606176, 0.43531467],
#        [0.33011294, 0.646156  , 0.7141945 ],
#        [0.32807211, 0.1457262 , 0.94788528]])

# %%
sum(M)
# Out:
# array([1.51947511, 1.09794395, 2.09739445])

# %%
M.sum()
# Out:
# 4.7148135089621155

# %%
M.min(axis=0)
# Out:
# array([0.32807211, 0.1457262 , 0.43531467])

# %%
M.max(axis=1)
# Out:
# array([0.86129005, 0.7141945 , 0.94788528])

# %%
a=np.array([1,2,3])
b=np.array([4,5,6])

# %%
a+b
# Out:
# array([5, 7, 9])

# %%
a+5
# Out:
# array([6, 7, 8])

# %%
M=np.ones(9).reshape(3,3)

# %%
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
M.shape
# Out:
# (3, 3)

# %%
a.shape
# Out:
# (3,)

# %%
M+a
# Out:
# array([[2., 3., 4.],
#        [2., 3., 4.],
#        [2., 3., 4.]])

# %%
a=np.arange(3)
b=np.arange(3)[:,np.newaxis]

# %%
print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
print(a.shape)
print(b.shape)
# Out:
# (3,)
# (3, 1)

# %%
a+b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
a+1+2*b
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [5, 6, 7]])

# %%
M=np.ones((3,2))
a=np.arange(3)

# %%
M
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
a
# Out:
# array([0, 1, 2])

# %%
print(M.shape)
print(a.shape)
# Out:
# (3, 2)
# (3,)

# %%
M+a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 M+a
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
a[:,np.newaxis].shape
# Out:
# (3, 1)

# %%
a[:,np.newaxis]
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
M+a[:,np.newaxis]
# Out:
# array([[1., 1.],
#        [2., 2.],
#        [3., 3.]])

# %%
x=np.array([1,2,3,4,5])

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(x<3)
# Out:
# [ True  True False False False]

# %%
np.less(x,3)
# Out:
# array([ True,  True, False, False, False])

# %%
print("x>3",x>3)
print("x>3",np.greater(x,3))
# Out:
# x>3 [False False False  True  True]
# x>3 [False False False  True  True]

# %%
print("x<=3",x<=3)
print("x<=3",np.less_equal(x,3))
# Out:
# x<=3 [ True  True  True False False]
# x<=3 [ True  True  True False False]

# %%
print("x>=3",x>=3)
print("x>=3",np.greater_equal(x,3))
# Out:
# x>=3 [False False  True  True  True]
# x>=3 [False False  True  True  True]

# %%
rng=np.random.RandomState(0)
x=rng.randint(10,size=(3,4))

# %%
x
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %%
x<6
# Out:
# array([[ True,  True,  True,  True],
#        [False, False,  True,  True],
#        [ True,  True, False, False]])

# %%
np.count_nonzero(x<6)
# Out:
# 8

# %%
np.sum(x<6)
# Out:
# 8

# %%
np.sum(x<6,axis=1)
# Out:
# array([4, 2, 2])

# %%
np.sum(x<6,axis=0)
# Out:
# array([2, 2, 2, 2])

# %%
x
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %%
np.any(x<6)
# Out:
# True

# %%
np.any(x<0)
# Out:
# False

# %%
np.all(x<0,axis=1)
# Out:
# array([False, False, False])

# %%
np.all(x<9,axis=1)
# Out:
# array([ True, False,  True])

# %% [markdown]
# # part2

# %%
import pandas as pd

# %%
df=pd.read_csv(r"seattle-weather.csv",encoding='utf-8',engine='python')

# %%
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0       2012/1/1            0.0      12.8       5.0   4.7  drizzle
# 1       2012/1/2           10.9      10.6       2.8   4.5     rain
# 2       2012/1/3            0.8      11.7       7.2   2.3     rain
# 3       2012/1/4           20.3      12.2       5.6   4.7     rain
# 4       2012/1/5            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015/12/27            8.6       4.4       1.7   2.9      fog
# 1457  2015/12/28            1.5       5.0       1.7   1.3      fog
# 1458  2015/12/29            0.0       7.2       0.6   2.6      fog
# 1459  2015/12/30            0.0       5.6      -1.0   3.4      sun
# 1460  2015/12/31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df['precipitation']
# Out:
# 0        0.0
# 1       10.9
# 2        0.8
# 3       20.3
# 4        1.3
#         ...
# 1456     8.6
# 1457     1.5
# 1458     0.0
# 1459     0.0
# 1460     0.0
# Name: precipitation, Length: 1461, dtype: float64

# %%
pd.set_option('display.max_rows',None)

# %%
np.sum(df['precipitation']==0)
# Out:
# 838

# %%
np.sum(df['precipitation']!=0)
# Out:
# 623

# %%
df['precipitation']
# Out:
# 0        0.0
# 1       10.9
# 2        0.8
# 3       20.3
# 4        1.3
# 5        2.5
# 6        0.0
# 7        0.0
# 8        4.3
# 9        1.0
# 10       0.0
# 11       0.0
# 12       0.0
# 13       4.1
# 14       5.3
# 15       2.5
# 16       8.1
# 17      19.8
# 18      15.2
# 19      13.5
# 20       3.0
# 21       6.1
# 22       0.0
# 23       8.6
# 24       8.1
# 25       4.8
# 26       0.0
# 27       0.0
# 28      27.7
# 29       3.6
# 30       1.8
# 31      13.5
# 32       0.0
# 33       0.0
# 34       0.0
# 35       0.0
# 36       0.0
# 37       0.3
# 38       2.8
# 39       2.5
# 40       2.5
# 41       0.8
# 42       1.0
# 43      11.4
# 44       2.5
# 45       0.0
# 46       1.8
# 47      17.3
# 48       6.4
# 49       0.0
# 50       3.0
# 51       0.8
# 52       8.6
# 53       0.0
# 54      11.4
# 55       0.0
# 56       1.3
# 57       0.0
# 58       3.6
# 59       0.8
# 60       0.0
# 61       2.0
# 62       0.0
# 63       0.0
# 64       6.9
# 65       0.5
# ...

# %%
df['temp_max']
# Out:
# 0       12.8
# 1       10.6
# 2       11.7
# 3       12.2
# 4        8.9
# 5        4.4
# 6        7.2
# 7       10.0
# 8        9.4
# 9        6.1
# 10       6.1
# 11       6.1
# 12       5.0
# 13       4.4
# 14       1.1
# 15       1.7
# 16       3.3
# 17       0.0
# 18      -1.1
# 19       7.2
# 20       8.3
# 21       6.7
# 22       8.3
# 23      10.0
# 24       8.9
# 25       8.9
# 26       6.7
# 27       6.7
# 28       9.4
# 29       8.3
# 30       9.4
# 31       8.9
# 32       8.3
# 33      14.4
# 34      15.6
# 35      13.9
# 36      16.1
# 37      15.6
# 38      10.0
# 39      11.1
# 40      12.8
# 41       8.9
# 42       8.3
# 43       7.2
# 44       6.7
# 45       7.2
# 46       7.2
# 47      10.0
# 48       6.7
# 49       6.7
# 50       7.8
# 51      10.0
# 52      10.0
# 53       8.3
# 54       6.7
# 55       7.2
# 56       5.0
# 57       6.7
# 58       6.7
# 59       5.0
# 60       6.1
# 61       6.7
# 62      12.2
# 63      10.6
# 64       7.8
# 65       6.7
# ...

# %%
np.sum((df['precipitation']<15)&(df['precipitation']>8))
# Out:
# 100

# %%
((df['precipitation']<15)&(df['precipitation']>8))==true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [192], in <cell line: 1>()
# ----> 1 ((df['precipitation']<15)&(df['precipitation']>8))==true
#
# NameError: name 'true' is not defined

# %%
x
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %%
x<5
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True, False],
#        [ True,  True, False, False]])

# %%
x[x<5]
# Out:
# array([0, 3, 3, 3, 2, 4])

# %%
rain=df['precipitation']>0

# %%
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1456     True
# 1457     True
# 1458    False
# 1459    False
# 1460    False
# Name: precipitation, Length: 1461, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
df['precipitation'][0:100]
# Out:
# 0      0.0
# 1     10.9
# 2      0.8
# 3     20.3
# 4      1.3
#       ...
# 95     4.6
# 96     0.3
# 97     0.0
# 98     0.0
# 99     0.0
# Name: precipitation, Length: 100, dtype: float64

# %%
df['precipitation'][rain]
# Out:
# 1       10.9
# 2        0.8
# 3       20.3
# 4        1.3
# 5        2.5
#         ...
# 1452     6.1
# 1453     2.5
# 1454     5.8
# 1456     8.6
# 1457     1.5
# Name: precipitation, Length: 623, dtype: float64

# %%
pd.set_option('display.max_rows',None)

# %%
df['precipitation'][rain]
# Out:
# 1       10.9
# 2        0.8
# 3       20.3
# 4        1.3
# 5        2.5
# 8        4.3
# 9        1.0
# 13       4.1
# 14       5.3
# 15       2.5
# 16       8.1
# 17      19.8
# 18      15.2
# 19      13.5
# 20       3.0
# 21       6.1
# 23       8.6
# 24       8.1
# 25       4.8
# 28      27.7
# 29       3.6
# 30       1.8
# 31      13.5
# 37       0.3
# 38       2.8
# 39       2.5
# 40       2.5
# 41       0.8
# 42       1.0
# 43      11.4
# 44       2.5
# 46       1.8
# 47      17.3
# 48       6.4
# 50       3.0
# 51       0.8
# 52       8.6
# 54      11.4
# 56       1.3
# 58       3.6
# 59       0.8
# 61       2.0
# 64       6.9
# 65       0.5
# 68       3.6
# 69      10.4
# 70      13.7
# 71      19.3
# 72       9.4
# 73       8.6
# 74      23.9
# 75       8.4
# 76       9.4
# 77       3.6
# 78       2.0
# 79       3.6
# 80       1.3
# 81       4.1
# 86       4.8
# 87       1.3
# 88      27.4
# 89       5.6
# 90      13.2
# 91       1.5
# 93       1.5
# 95       4.6
# ...
